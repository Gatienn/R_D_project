# %%
import numpy  as np
import matplotlib.pyplot as plt

# %%
import script_simulation.py
# Out:
# nombre d'états discrets visités :  6
# sab = 0.750771982139909 sbc = 0.12302160752344793 sca = 0.07554774563243305
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import script_simulation.py
#
# ModuleNotFoundError: No module named 'script_simulation.py'; 'script_simulation' is not a package
